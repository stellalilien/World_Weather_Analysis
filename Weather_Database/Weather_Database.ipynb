# %%
# Import the dependencies

import pandas as pd
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# Import weather API key

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
# Create a list for holding cities

cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create the empty list to hold the weather data

city_data = []

print('Beginning Data Retrieval     ')
print('-----------------------------')

# Create counters

record_count = 1
set_count = 1

# Loop through the city list

for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint url with each city
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1
    
    # Run an API request for each city
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Country": city_country})
    
    except:
        print("City not found. Skipping...")
        pass

print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | quang ngai
# Processing Record 3 of Set 1 | saint-augustin
# Processing Record 4 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | jasper
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | maroantsetra
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | jimenez
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | tuatapere
# Processing Record 16 of Set 1 | kidal
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | merrill
# Processing Record 19 of Set 1 | kaberamaido
# Processing Record 20 of Set 1 | kahului
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | fortuna
# Processing Record 23 of Set 1 | kargasok
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | vigrestad
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | am timan
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | azar shahr
# City not found. Skipping...
# Processing Record 37 of Set 1 | port hardy
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | alexandria
# Processing Record 45 of Set 1 | kenai
# Processing Record 46 of Set 1 | naze
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | portland
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | mzimba
# Processing Record 8 of Set 2 | yambio
# Processing Record 9 of Set 2 | oistins
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | marawi
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | mweka
# Processing Record 14 of Set 2 | bowen
# Processing Record 15 of Set 2 | lugovoy
# Processing Record 16 of Set 2 | markova
# Processing Record 17 of Set 2 | dharampur
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | saint-ambroise
# Processing Record 24 of Set 2 | sao geraldo do araguaia
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | bonham
# Processing Record 27 of Set 2 | katherine
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | kaduna
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | bugalagrande
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | genthin
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | bosaso
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | sorland
# Processing Record 43 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 2 | lavrentiya
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | felanitx
# Processing Record 50 of Set 2 | mendi
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | punjai puliyampatti
# Processing Record 4 of Set 3 | stony plain
# Processing Record 5 of Set 3 | araguaina
# Processing Record 6 of Set 3 | sadovyy
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | mancora
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | santa marta
# Processing Record 12 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | port lavaca
# Processing Record 15 of Set 3 | uige
# Processing Record 16 of Set 3 | nanzhang
# Processing Record 17 of Set 3 | tomatlan
# Processing Record 18 of Set 3 | yar-sale
# Processing Record 19 of Set 3 | tabou
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | cockburn town
# Processing Record 22 of Set 3 | mkushi
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | broken hill
# Processing Record 25 of Set 3 | teguise
# Processing Record 26 of Set 3 | batagay-alyta
# Processing Record 27 of Set 3 | sakaiminato
# Processing Record 28 of Set 3 | coquimbo
# Processing Record 29 of Set 3 | sakakah
# Processing Record 30 of Set 3 | alofi
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | hami
# Processing Record 34 of Set 3 | rumonge
# Processing Record 35 of Set 3 | qom
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | parlakimidi
# Processing Record 38 of Set 3 | ban phai
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | kailua
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | bambanglipuro
# Processing Record 43 of Set 3 | rawlins
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | sunrise manor
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | butembo
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | samarai
# Processing Record 50 of Set 3 | winchester
# Processing Record 1 of Set 4 | quatre cocos
# Processing Record 2 of Set 4 | kwinana
# Processing Record 3 of Set 4 | paamiut
# Processing Record 4 of Set 4 | rocha
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | hay river
# Processing Record 7 of Set 4 | yulara
# Processing Record 8 of Set 4 | sahuaripa
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | balabac
# Processing Record 11 of Set 4 | paraiso
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | honningsvag
# Processing Record 14 of Set 4 | maldonado
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | henties bay
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | gardone val trompia
# Processing Record 20 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 4 | biak
# Processing Record 22 of Set 4 | zhuanghe
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | chimbote
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 4 | flin flon
# Processing Record 29 of Set 4 | tagusao
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | sorong
# Processing Record 33 of Set 4 | jian
# Processing Record 34 of Set 4 | kuminskiy
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | hasaki
# Processing Record 37 of Set 4 | lobito
# Processing Record 38 of Set 4 | erenhot
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | lesnoy
# Processing Record 41 of Set 4 | russellville
# Processing Record 42 of Set 4 | fukue
# Processing Record 43 of Set 4 | sept-iles
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | veisiejai
# Processing Record 46 of Set 4 | bereznik
# Processing Record 47 of Set 4 | bangolo
# Processing Record 48 of Set 4 | maceio
# Processing Record 49 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | los llanos de aridane
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | djibo
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | dwarka
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | conde
# Processing Record 11 of Set 5 | ninghai
# Processing Record 12 of Set 5 | trinidad
# Processing Record 13 of Set 5 | manoel urbano
# Processing Record 14 of Set 5 | lelydorp
# Processing Record 15 of Set 5 | twin falls
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | karratha
# Processing Record 19 of Set 5 | opuwo
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | lovozero
# Processing Record 22 of Set 5 | talnakh
# Processing Record 23 of Set 5 | iqaluit
# Processing Record 24 of Set 5 | casper
# Processing Record 25 of Set 5 | berlevag
# Processing Record 26 of Set 5 | tongliao
# Processing Record 27 of Set 5 | ugoofaaru
# Processing Record 28 of Set 5 | dawson creek
# Processing Record 29 of Set 5 | pundaguitan
# Processing Record 30 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 5 | sanary-sur-mer
# Processing Record 32 of Set 5 | lincoln
# Processing Record 33 of Set 5 | ruston
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | port macquarie
# Processing Record 37 of Set 5 | price
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | pimentel
# Processing Record 40 of Set 5 | north bend
# Processing Record 41 of Set 5 | gabrovo
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | chimoio
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | marystown
# Processing Record 47 of Set 5 | carnot
# Processing Record 48 of Set 5 | red bluff
# Processing Record 49 of Set 5 | brae
# Processing Record 50 of Set 5 | storsteinnes
# Processing Record 1 of Set 6 | peleduy
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | riyadh
# Processing Record 4 of Set 6 | cumpas
# Processing Record 5 of Set 6 | alta floresta
# Processing Record 6 of Set 6 | katsuura
# Processing Record 7 of Set 6 | shache
# Processing Record 8 of Set 6 | dharchula
# Processing Record 9 of Set 6 | saint-joseph
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | dryden
# Processing Record 12 of Set 6 | hovd
# Processing Record 13 of Set 6 | shingu
# Processing Record 14 of Set 6 | road town
# Processing Record 15 of Set 6 | kamenka
# Processing Record 16 of Set 6 | mahebourg
# Processing Record 17 of Set 6 | qaqortoq
# Processing Record 18 of Set 6 | kohlu
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | pevek
# Processing Record 21 of Set 6 | juarez
# Processing Record 22 of Set 6 | uinskoye
# Processing Record 23 of Set 6 | ranibennur
# Processing Record 24 of Set 6 | chifeng
# Processing Record 25 of Set 6 | tura
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 6 | pringsewu
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | nador
# Processing Record 32 of Set 6 | rovaniemi
# Processing Record 33 of Set 6 | lokosovo
# Processing Record 34 of Set 6 | faanui
# Processing Record 35 of Set 6 | dalumangcob
# Processing Record 36 of Set 6 | kislyakovskaya
# Processing Record 37 of Set 6 | faya
# Processing Record 38 of Set 6 | mount isa
# Processing Record 39 of Set 6 | taminango
# Processing Record 40 of Set 6 | santa cruz
# Processing Record 41 of Set 6 | sur
# Processing Record 42 of Set 6 | saryozek
# Processing Record 43 of Set 6 | maarianhamina
# Processing Record 44 of Set 6 | ipil
# Processing Record 45 of Set 6 | roald
# Processing Record 46 of Set 6 | mana
# Processing Record 47 of Set 6 | makokou
# Processing Record 48 of Set 6 | chapais
# Processing Record 49 of Set 6 | accra
# Processing Record 50 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | manfredonia
# Processing Record 2 of Set 7 | santiago del estero
# Processing Record 3 of Set 7 | tomaszow lubelski
# Processing Record 4 of Set 7 | wenling
# Processing Record 5 of Set 7 | jining
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | rudbar
# Processing Record 8 of Set 7 | lincoln village
# Processing Record 9 of Set 7 | nokaneng
# Processing Record 10 of Set 7 | akdepe
# Processing Record 11 of Set 7 | padang
# Processing Record 12 of Set 7 | deputatskiy
# Processing Record 13 of Set 7 | luau
# Processing Record 14 of Set 7 | tigre
# Processing Record 15 of Set 7 | ayr
# Processing Record 16 of Set 7 | kijang
# Processing Record 17 of Set 7 | abha
# Processing Record 18 of Set 7 | sola
# Processing Record 19 of Set 7 | yanam
# Processing Record 20 of Set 7 | verkhnevilyuysk
# Processing Record 21 of Set 7 | aden
# Processing Record 22 of Set 7 | kumluca
# Processing Record 23 of Set 7 | tilichiki
# Processing Record 24 of Set 7 | kalas
# Processing Record 25 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 7 | normandin
# Processing Record 27 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 7 | sciacca
# Processing Record 29 of Set 7 | general roca
# Processing Record 30 of Set 7 | kajaani
# Processing Record 31 of Set 7 | saint-philippe
# Processing Record 32 of Set 7 | harper
# Processing Record 33 of Set 7 | imisli
# City not found. Skipping...
# Processing Record 34 of Set 7 | calapi
# Processing Record 35 of Set 7 | belyy yar
# Processing Record 36 of Set 7 | cabedelo
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | odweyne
# Processing Record 39 of Set 7 | garissa
# Processing Record 40 of Set 7 | veraval
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | richards bay
# Processing Record 43 of Set 7 | humboldt
# Processing Record 44 of Set 7 | ochamchira
# Processing Record 45 of Set 7 | sidi ali
# Processing Record 46 of Set 7 | bud
# Processing Record 47 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 7 | kawambwa
# Processing Record 49 of Set 7 | bangui
# Processing Record 50 of Set 7 | waddan
# Processing Record 1 of Set 8 | haines junction
# Processing Record 2 of Set 8 | taoudenni
# Processing Record 3 of Set 8 | shelburne
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | nouakchott
# Processing Record 6 of Set 8 | olafsvik
# Processing Record 7 of Set 8 | urumqi
# Processing Record 8 of Set 8 | aykino
# Processing Record 9 of Set 8 | kashin
# Processing Record 10 of Set 8 | la ronge
# Processing Record 11 of Set 8 | shaping
# Processing Record 12 of Set 8 | delta
# Processing Record 13 of Set 8 | emirdag
# Processing Record 14 of Set 8 | halifax
# Processing Record 15 of Set 8 | fort nelson
# Processing Record 16 of Set 8 | belluru
# Processing Record 17 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 8 | bolivar
# Processing Record 19 of Set 8 | bongaree
# Processing Record 20 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | finschhafen
# Processing Record 22 of Set 8 | bryukhovetskaya
# Processing Record 23 of Set 8 | chara
# Processing Record 24 of Set 8 | malanje
# Processing Record 25 of Set 8 | zhigansk
# Processing Record 26 of Set 8 | kerouane
# Processing Record 27 of Set 8 | nikel
# Processing Record 28 of Set 8 | mildura
# Processing Record 29 of Set 8 | kampong cham
# Processing Record 30 of Set 8 | sao joao da barra
# Processing Record 31 of Set 8 | camocim
# Processing Record 32 of Set 8 | bure
# Processing Record 33 of Set 8 | anloga
# Processing Record 34 of Set 8 | jaisalmer
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | clonakilty
# Processing Record 37 of Set 8 | klyuchi
# Processing Record 38 of Set 8 | khatanga
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | vikhorevka
# Processing Record 41 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | kudat
# Processing Record 44 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 8 | porto novo
# Processing Record 46 of Set 8 | san policarpo
# Processing Record 47 of Set 8 | karasjok
# Processing Record 48 of Set 8 | ilan
# Processing Record 49 of Set 8 | stranraer
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 9 | sitka
# Processing Record 3 of Set 9 | paka
# Processing Record 4 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 5 of Set 9 | cherepovets
# Processing Record 6 of Set 9 | derzhavinsk
# Processing Record 7 of Set 9 | kirakira
# Processing Record 8 of Set 9 | stillwater
# Processing Record 9 of Set 9 | birjand
# Processing Record 10 of Set 9 | aswan
# Processing Record 11 of Set 9 | morant bay
# Processing Record 12 of Set 9 | abu samrah
# Processing Record 13 of Set 9 | nioro
# Processing Record 14 of Set 9 | kathmandu
# Processing Record 15 of Set 9 | gushikawa
# Processing Record 16 of Set 9 | kismayo
# Processing Record 17 of Set 9 | belmonte
# Processing Record 18 of Set 9 | awjilah
# Processing Record 19 of Set 9 | ambon
# Processing Record 20 of Set 9 | saint-louis
# Processing Record 21 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 9 | batticaloa
# Processing Record 23 of Set 9 | manaure
# Processing Record 24 of Set 9 | ayolas
# Processing Record 25 of Set 9 | taltal
# Processing Record 26 of Set 9 | fenoarivo
# Processing Record 27 of Set 9 | mirnyy
# Processing Record 28 of Set 9 | le port
# Processing Record 29 of Set 9 | malindi
# Processing Record 30 of Set 9 | ilembo
# Processing Record 31 of Set 9 | neiafu
# Processing Record 32 of Set 9 | gizo
# Processing Record 33 of Set 9 | vadso
# Processing Record 34 of Set 9 | cherskiy
# Processing Record 35 of Set 9 | port keats
# Processing Record 36 of Set 9 | foam lake
# Processing Record 37 of Set 9 | kununurra
# Processing Record 38 of Set 9 | bakchar
# Processing Record 39 of Set 9 | burnie
# Processing Record 40 of Set 9 | gari
# Processing Record 41 of Set 9 | chernyshevskiy
# Processing Record 42 of Set 9 | hofn
# Processing Record 43 of Set 9 | ust-barguzin
# Processing Record 44 of Set 9 | revda
# Processing Record 45 of Set 9 | preston
# Processing Record 46 of Set 9 | chuy
# Processing Record 47 of Set 9 | muroto
# Processing Record 48 of Set 9 | dabakala
# Processing Record 49 of Set 9 | tra vinh
# Processing Record 50 of Set 9 | tanete
# Processing Record 1 of Set 10 | todos santos
# Processing Record 2 of Set 10 | tupik
# Processing Record 3 of Set 10 | vanino
# Processing Record 4 of Set 10 | hamada
# Processing Record 5 of Set 10 | rio grande
# Processing Record 6 of Set 10 | santa lucia
# Processing Record 7 of Set 10 | iralaya
# Processing Record 8 of Set 10 | talcahuano
# Processing Record 9 of Set 10 | meulaboh
# Processing Record 10 of Set 10 | smithers
# Processing Record 11 of Set 10 | ventersburg
# Processing Record 12 of Set 10 | navahrudak
# Processing Record 13 of Set 10 | srednekolymsk
# Processing Record 14 of Set 10 | boralday
# Processing Record 15 of Set 10 | falam
# Processing Record 16 of Set 10 | naro-fominsk
# Processing Record 17 of Set 10 | guarapari
# Processing Record 18 of Set 10 | kholmogory
# Processing Record 19 of Set 10 | bambous virieux
# Processing Record 20 of Set 10 | coromandel
# Processing Record 21 of Set 10 | alenquer
# Processing Record 22 of Set 10 | namatanai
# Processing Record 23 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 10 | xining
# Processing Record 25 of Set 10 | baruun-urt
# Processing Record 26 of Set 10 | ca mau
# Processing Record 27 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 28 of Set 10 | mercedes
# Processing Record 29 of Set 10 | gat
# Processing Record 30 of Set 10 | xam nua
# Processing Record 31 of Set 10 | erdenet
# Processing Record 32 of Set 10 | makriyialos
# City not found. Skipping...
# Processing Record 33 of Set 10 | nurota
# Processing Record 34 of Set 10 | mao
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 10 | kilindoni
# Processing Record 38 of Set 10 | mayo
# Processing Record 39 of Set 10 | ust-kuyga
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | nelson bay
# Processing Record 42 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 10 | ferrol
# Processing Record 44 of Set 10 | harer
# Processing Record 45 of Set 10 | biloli
# Processing Record 46 of Set 10 | saint anthony
# Processing Record 47 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 10 | ponta delgada
# Processing Record 49 of Set 10 | weinan
# Processing Record 50 of Set 10 | ibipeba
# Processing Record 1 of Set 11 | caucaia
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | victor harbor
# Processing Record 4 of Set 11 | qasigiannguit
# Processing Record 5 of Set 11 | mayumba
# Processing Record 6 of Set 11 | florence
# Processing Record 7 of Set 11 | anito
# Processing Record 8 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 11 | natal
# Processing Record 10 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 11 of Set 11 | moindou
# Processing Record 12 of Set 11 | sampit
# Processing Record 13 of Set 11 | canton
# Processing Record 14 of Set 11 | vestmannaeyjar
# Processing Record 15 of Set 11 | bara
# Processing Record 16 of Set 11 | qiongshan
# Processing Record 17 of Set 11 | riohacha
# Processing Record 18 of Set 11 | ossora
# Processing Record 19 of Set 11 | college
# Processing Record 20 of Set 11 | fairbanks
# Processing Record 21 of Set 11 | namibe
# Processing Record 22 of Set 11 | victoria
# Processing Record 23 of Set 11 | corinto
# Processing Record 24 of Set 11 | tokur
# Processing Record 25 of Set 11 | kaduqli
# Processing Record 26 of Set 11 | ust-tsilma
# Processing Record 27 of Set 11 | marhaura
# Processing Record 28 of Set 11 | joshimath
# Processing Record 29 of Set 11 | bilma
# Processing Record 30 of Set 11 | kirillov
# Processing Record 31 of Set 11 | san cristobal
# Processing Record 32 of Set 11 | burgersdorp
# Processing Record 33 of Set 11 | usinsk
# Processing Record 34 of Set 11 | the valley
# Processing Record 35 of Set 11 | linares
# Processing Record 36 of Set 11 | plettenberg bay
# Processing Record 37 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 11 | valdivia
# Processing Record 39 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 11 | colac
# Processing Record 41 of Set 11 | brive-la-gaillarde
# Processing Record 42 of Set 11 | kupang
# Processing Record 43 of Set 11 | kantang
# Processing Record 44 of Set 11 | anderson
# Processing Record 45 of Set 11 | rio gallegos
# Processing Record 46 of Set 11 | yerbogachen
# Processing Record 47 of Set 11 | kotido
# Processing Record 48 of Set 11 | huarmey
# Processing Record 49 of Set 11 | kem
# Processing Record 50 of Set 11 | green river
# Processing Record 1 of Set 12 | cananea
# Processing Record 2 of Set 12 | boguchany
# Processing Record 3 of Set 12 | teahupoo
# Processing Record 4 of Set 12 | ferry pass
# Processing Record 5 of Set 12 | bairiki
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | aleksandrov gay
# Processing Record 8 of Set 12 | jiazi
# Processing Record 9 of Set 12 | turukhansk
# Processing Record 10 of Set 12 | grand gaube
# Processing Record 11 of Set 12 | raton
# Processing Record 12 of Set 12 | anori
# Processing Record 13 of Set 12 | prince rupert
# Processing Record 14 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 12 | hambantota
# Processing Record 16 of Set 12 | palmer
# Processing Record 17 of Set 12 | winnemucca
# Processing Record 18 of Set 12 | mahajanga
# Processing Record 19 of Set 12 | ibotirama
# Processing Record 20 of Set 12 | farim
# Processing Record 21 of Set 12 | margate
# Processing Record 22 of Set 12 | yate
# Processing Record 23 of Set 12 | pipri
# Processing Record 24 of Set 12 | nouadhibou
# Processing Record 25 of Set 12 | pueblo nuevo
# Processing Record 26 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 27 of Set 12 | sao gabriel da cachoeira
# Processing Record 28 of Set 12 | pacific grove
# Processing Record 29 of Set 12 | kemijarvi
# Processing Record 30 of Set 12 | rajauri
# Processing Record 31 of Set 12 | vao
# Processing Record 32 of Set 12 | tocopilla
# Processing Record 33 of Set 12 | gewane
# Processing Record 34 of Set 12 | hovsan
# Processing Record 35 of Set 12 | beatrice
# Processing Record 36 of Set 12 | arman
# Processing Record 37 of Set 12 | sanda
# Processing Record 38 of Set 12 | ciro marina
# Processing Record 39 of Set 12 | dalbandin
# Processing Record 40 of Set 12 | port hawkesbury
# Processing Record 41 of Set 12 | itaberai
# Processing Record 42 of Set 12 | aklavik
# Processing Record 43 of Set 12 | celestun
# Processing Record 44 of Set 12 | asau
# Processing Record 45 of Set 12 | narrabri
# Processing Record 46 of Set 12 | cabatuan
# Processing Record 47 of Set 12 | armizonskoye
# Processing Record 48 of Set 12 | kings point
# Processing Record 49 of Set 12 | tuy hoa
# Processing Record 50 of Set 12 | tandil
# Processing Record 1 of Set 13 | boa vista
# Processing Record 2 of Set 13 | rorvik
# Processing Record 3 of Set 13 | korla
# Processing Record 4 of Set 13 | yaan
# Processing Record 5 of Set 13 | kaputa
# Processing Record 6 of Set 13 | hun
# Processing Record 7 of Set 13 | juneau
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | pitkyaranta
# Processing Record 10 of Set 13 | bereda
# Processing Record 11 of Set 13 | wenatchee
# Processing Record 12 of Set 13 | coronado
# Processing Record 13 of Set 13 | monrovia
# Processing Record 14 of Set 13 | fayaoue
# Processing Record 15 of Set 13 | marsa matruh
# Processing Record 16 of Set 13 | east wenatchee bench
# Processing Record 17 of Set 13 | smirnykh
# Processing Record 18 of Set 13 | springbok
# Processing Record 19 of Set 13 | agirish
# Processing Record 20 of Set 13 | elizabeth city
# Processing Record 21 of Set 13 | changji
# Processing Record 22 of Set 13 | usevya
# Processing Record 23 of Set 13 | shimoda
# Processing Record 24 of Set 13 | huntsville
# Processing Record 25 of Set 13 | puerto madryn
# Processing Record 26 of Set 13 | yarmouth
# Processing Record 27 of Set 13 | najran
# Processing Record 28 of Set 13 | gemena
# Processing Record 29 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 13 | planaltina
# Processing Record 31 of Set 13 | calama
# Processing Record 32 of Set 13 | ito
# Processing Record 33 of Set 13 | nukus
# Processing Record 34 of Set 13 | mogadishu
# Processing Record 35 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 13 | camopi
# Processing Record 37 of Set 13 | torit
# Processing Record 38 of Set 13 | kudahuvadhoo
# Processing Record 39 of Set 13 | atambua
# Processing Record 40 of Set 13 | baracoa
# Processing Record 41 of Set 13 | khorinsk
# Processing Record 42 of Set 13 | matara
# Processing Record 43 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 13 | moron
# Processing Record 45 of Set 13 | tukums
# Processing Record 46 of Set 13 | chipinge
# Processing Record 47 of Set 13 | chapleau
# Processing Record 48 of Set 13 | tautira
# Processing Record 49 of Set 13 | shar
# Processing Record 50 of Set 13 | norden
# Processing Record 1 of Set 14 | timmins
# Processing Record 2 of Set 14 | careiro da varzea
# Processing Record 3 of Set 14 | buribay
# Processing Record 4 of Set 14 | terenga
# City not found. Skipping...
# Processing Record 5 of Set 14 | krasnoselkup
# Processing Record 6 of Set 14 | ruteng
# Processing Record 7 of Set 14 | mehran
# Processing Record 8 of Set 14 | sulurpeta
# City not found. Skipping...
# Processing Record 9 of Set 14 | sainte-marie
# Processing Record 10 of Set 14 | nizwa
# Processing Record 11 of Set 14 | bindura
# Processing Record 12 of Set 14 | callaway
# Processing Record 13 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 14 of Set 14 | preeceville
# Processing Record 15 of Set 14 | baghdad
# Processing Record 16 of Set 14 | muzhi
# Processing Record 17 of Set 14 | mardin
# Processing Record 18 of Set 14 | camacha
# Processing Record 19 of Set 14 | lufilufi
# Processing Record 20 of Set 14 | sabha
# Processing Record 21 of Set 14 | rajapalaiyam
# Processing Record 22 of Set 14 | christchurch
# Processing Record 23 of Set 14 | wuning
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | great falls
# Processing Record 26 of Set 14 | kokopo
# Processing Record 27 of Set 14 | vanimo
# Processing Record 28 of Set 14 | eureka
# Processing Record 29 of Set 14 | altay
# Processing Record 30 of Set 14 | waingapu
# Processing Record 31 of Set 14 | benito juarez
# Processing Record 32 of Set 14 | marrakesh
# Processing Record 33 of Set 14 | hailey
# Processing Record 34 of Set 14 | noumea
# Processing Record 35 of Set 14 | buraydah
# Processing Record 36 of Set 14 | guadalupe y calvo
# Processing Record 37 of Set 14 | middelburg
# Processing Record 38 of Set 14 | dawei
# Processing Record 39 of Set 14 | sioux lookout
# Processing Record 40 of Set 14 | pacifica
# Processing Record 41 of Set 14 | negombo
# Processing Record 42 of Set 14 | richmond
# Processing Record 43 of Set 14 | peniche
# Processing Record 44 of Set 14 | maunabo
# Processing Record 45 of Set 14 | hobyo
# Processing Record 46 of Set 14 | chumikan
# Processing Record 47 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 48 of Set 14 | outjo
# Processing Record 49 of Set 14 | pemberton
# Processing Record 50 of Set 14 | beloha
# Processing Record 1 of Set 15 | coos bay
# Processing Record 2 of Set 15 | guican
# Processing Record 3 of Set 15 | avera
# Processing Record 4 of Set 15 | asosa
# Processing Record 5 of Set 15 | fairfield
# Processing Record 6 of Set 15 | sosnovo-ozerskoye
# Processing Record 7 of Set 15 | klang
# Processing Record 8 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 15 | nizhnevartovsk
# Processing Record 10 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 11 of Set 15 | simbahan
# Processing Record 12 of Set 15 | tonantins
# Processing Record 13 of Set 15 | saint-denis
# Processing Record 14 of Set 15 | mitsamiouli
# Processing Record 15 of Set 15 | salantai
# Processing Record 16 of Set 15 | tsiroanomandidy
# Processing Record 17 of Set 15 | escarcega
# Processing Record 18 of Set 15 | belaya gora
# Processing Record 19 of Set 15 | kankon
# Processing Record 20 of Set 15 | nemuro
# Processing Record 21 of Set 15 | marquette
# Processing Record 22 of Set 15 | el rosario
# Processing Record 23 of Set 15 | storslett
# Processing Record 24 of Set 15 | thunder bay
# Processing Record 25 of Set 15 | stornoway
# Processing Record 26 of Set 15 | kinsale
# Processing Record 27 of Set 15 | jayanca
# Processing Record 28 of Set 15 | mus
# Processing Record 29 of Set 15 | wageningen
# Processing Record 30 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 15 | thinadhoo
# Processing Record 32 of Set 15 | madimba
# Processing Record 33 of Set 15 | rafraf
# Processing Record 34 of Set 15 | amot
# Processing Record 35 of Set 15 | diapaga
# Processing Record 36 of Set 15 | nyurba
# Processing Record 37 of Set 15 | egvekinot
# Processing Record 38 of Set 15 | lasa
# Processing Record 39 of Set 15 | hualmay
# Processing Record 40 of Set 15 | luwuk
# Processing Record 41 of Set 15 | bay roberts
# Processing Record 42 of Set 15 | dauriya
# Processing Record 43 of Set 15 | rehoboth
# Processing Record 44 of Set 15 | necochea
# Processing Record 45 of Set 15 | barrhead
# Processing Record 46 of Set 15 | bentiu
# Processing Record 47 of Set 15 | colares
# Processing Record 48 of Set 15 | cheney
# Processing Record 49 of Set 15 | jibuti
# Processing Record 50 of Set 15 | sarh
# Processing Record 1 of Set 16 | bucerias
# Processing Record 2 of Set 16 | mago
# Processing Record 3 of Set 16 | porto belo
# Processing Record 4 of Set 16 | menongue
# Processing Record 5 of Set 16 | pasighat
# Processing Record 6 of Set 16 | atar
# Processing Record 7 of Set 16 | dzaoudzi
# Processing Record 8 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 16 | killybegs
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton -33.6500  115.3333     73.96        41           0
# 1      Quang Ngai  15.1167  108.8000     68.72        94         100
# 2  Saint-Augustin  51.2260  -58.6502     -2.96        86         100
# 3    Norman Wells  65.2820 -126.8329    -12.96        64          75
# 4          Jasper  37.2001  -94.3502     29.01        50           0
# 5           Kapaa  22.0752 -159.3190     80.47        69           0
# 6    Ponta Do Sol  32.6667  -17.1000     65.71        66         100
# 7    Maroantsetra -15.4333   49.7333     76.66        81         100
# 8      Nikolskoye  59.7035   30.7861     19.29        90          74
# 9        Souillac -20.5167   57.5167     79.36        94          75
#
#    Wind Speed Current Description Country
# 0        2.98           clear sky      AU
# 1        6.24     overcast clouds      VN
# 2        7.90     overcast clouds      CA
# 3       21.85       broken clouds      CA
# 4        1.99           clear sky      US
# 5        1.99           clear sky      US
# 6        2.46     overcast clouds      PT
# 7        6.82     overcast clouds      MG
# 8       11.61       broken clouds      RU
# 9       11.50          light rain      MU

# %%
# Reorder columns

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     73.96        41           0
# 1      Quang Ngai      VN  15.1167  108.8000     68.72        94         100
# 2  Saint-Augustin      CA  51.2260  -58.6502     -2.96        86         100
# 3    Norman Wells      CA  65.2820 -126.8329    -12.96        64          75
# 4          Jasper      US  37.2001  -94.3502     29.01        50           0
# 5           Kapaa      US  22.0752 -159.3190     80.47        69           0
# 6    Ponta Do Sol      PT  32.6667  -17.1000     65.71        66         100
# 7    Maroantsetra      MG -15.4333   49.7333     76.66        81         100
# 8      Nikolskoye      RU  59.7035   30.7861     19.29        90          74
# 9        Souillac      MU -20.5167   57.5167     79.36        94          75
#
#    Wind Speed Current Description
# 0        2.98           clear sky
# 1        6.24     overcast clouds
# 2        7.90     overcast clouds
# 3       21.85       broken clouds
# 4        1.99           clear sky
# 5        1.99           clear sky
# 6        2.46     overcast clouds
# 7        6.82     overcast clouds
# 8       11.61       broken clouds
# 9       11.50          light rain

# %%
# Create output file

output_data_file = "WeatherPy_Database.csv"

# Export data to CSV

city_data_df.to_csv(output_data_file, index_label = "City_ID")
